# %% [markdown]
# ## My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# # Sathya Bhat
#
# I work as Machine learning engineer.

# %% [markdown]
# *I like data analytics as it gives me immense pleaseure to explore data and build stories*

# %% [markdown]
# ### small bit of code to add 1 with 1

# %%
ans = 1+1
print(ans)
# Out:
# 2

# %% [markdown]
# >Data science is cool
#
# I can make bulleted list too
#
# - line item 1
# - line item 2
# - line time 3
#
# ~Bye Bye~
